# %%
# import seaborn as sns
# titanic_df = sns.load_dataset('titanic')
# titanic_df.to_csv('titanic.csv')

# %%
# !pip install jupyter_ai
# %load_ext jupyter_ai_magics
# %env OPENAI_API_KEY = {YOUR_API_KEY}

# %%
# %%ai chatgpt
# Explain the Monty Hall problem in brief.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'chatgpt', 'Explain the Monty Hall problem in brief.\n')
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2475, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2473 with self.builtin_trap:
#    2474     args = (magic_arg_s, cell)
# -> 2475     result = fn(*args, **kwargs)
#    2477 # The code below prevents the output from being displayed
#    2478 # when using magics with decodator @output_can_be_silenced
#    2479 # when the last Python token in the expression is a ';'.
#    2480 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\lib\site-packages\jupyter_ai_magics\magics.py:590, in AiMagics.ai(self, line, cell)
#     587 ip = get_ipython()
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("titanic.csv")

# Create a single figure to make the plots using subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# Create a histogram of the Age column
df['age'].hist(ax=axes[0, 0])
axes[0, 0].set_title('Age distribution')

# Create a boxplot of the Fare column
df['fare'].plot(kind='box', ax=axes[0, 1])
axes[0, 1].set_title('Fare distribution')

# Create a scatter plot of the Fare and Age columns
df.plot(x='age', y='fare', kind='scatter', ax=axes[1, 0])
axes[1, 0].set_title('Fare vs Age')

# Create a pie chart of the Survived column
df['survived'].value_counts().plot.pie(ax=axes[1, 1], autopct='%1.1f%%')
axes[1, 1].set_title('Survival Rate')

# Show the plot
plt.show()
# Out:
# c:\Users\relat\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# %%ai chatgpt -f code
# Load the "titanic.csv" file. Do a univariate analysis.
# Write code to show the relevant plots. Use a single figure to make the plots using subplots.
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Titanic dataset from the csv file
df = pd.read_csv("titanic.csv")

# Create a figure with 3 subplots
fig, axes = plt.subplots(1, 3, figsize=(10, 4))

# Plot 1: Bar plot of passenger class counts
axes[0].bar(df["class"].unique(), df["class"].value_counts(sort=False), color="steelblue")
axes[0].set_xlabel("Passenger Class")
axes[0].set_ylabel("Count")
axes[0].set_title("Passenger Class")

# Plot 2: Bar plot of sex counts
axes[1].bar(df["sex"].unique(), df["sex"].value_counts(sort=False), color="skyblue")
axes[1].set_xlabel("Sex")
axes[1].set_ylabel("Count")
axes[1].set_title("Sex")

# Plot 3: Bar plot of survival counts
axes[2].bar(["Did not Survive", "survived"], df["survived"].value_counts(sort=False), color=["lightcoral", "limegreen"])
axes[2].set_xlabel("Survival")
axes[2].set_ylabel("Count")
axes[2].set_title("Survival")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plots
plt.show()

# %%
# %%ai chatgpt -f code
# Load the "titanic.csv" file. Do a univariate and multivariate analysis.
# Write code to show the relevant plots. Use a single figure to make the plots using subplots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("titanic.csv")

# Univariate Analysis

class_counts = df['class'].value_counts()
plt.figure(figsize=(4, 2))
sns.barplot(x=class_counts.index, y=class_counts.values, palette='viridis')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Passenger Class Distribution')
plt.show()

plt.figure(figsize=(4, 2))
sns.histplot(df['age'].dropna(), kde=True, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

gender_counts = df['sex'].value_counts()
plt.figure(figsize=(4, 2))
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'pink'])
plt.title('Gender Distribution')
plt.show()


# Multivariate Analysis

pclass_survival = pd.crosstab(df['class'], df['survived'])
plt.figure(figsize=(4, 2))
pclass_survival.plot(kind='bar', stacked=True, colormap='coolwarm')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Survival by Passenger Class')
plt.show()

correlation_data = df[['age', 'fare', 'survived']]
correlation_matrix = correlation_data.corr()
plt.figure(figsize=(4, 2))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix: Age, Fare, and Survived')
plt.show()

# %% [markdown]
# ## New start

# %%
# !pip install --upgrade pip
# Out:
# ...
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\relat\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\users\relat\anaconda3\lib\site-packages)

# %%
# !pip install jupyter_ai --upgrade
# Out:
# ...
#                                               0.0/930.7 kB ? eta -:--:--
#      ------------                           317.4/930.7 kB 6.5 MB/s eta 0:00:01
#      ----------------------------           696.3/930.7 kB 7.3 MB/s eta 0:00:01
#      -------------------------------------  921.6/930.7 kB 6.5 MB/s eta 0:00:01
#      -------------------------------------- 930.7/930.7 kB 5.9 MB/s eta 0:00:00
# ...
#                                               0.0/867.6 kB ? eta -:--:--
#      --------------                        337.9/867.6 kB 10.6 MB/s eta 0:00:01
#      ----------------------------           645.1/867.6 kB 8.1 MB/s eta 0:00:01
#      -------------------------------------- 867.6/867.6 kB 6.9 MB/s eta 0:00:00
# ...
#                                               0.0/2.0 MB ? eta -:--:--
#      --------                                 0.4/2.0 MB 12.9 MB/s eta 0:00:01
#      -------------                            0.7/2.0 MB 8.9 MB/s eta 0:00:01
# ...

# %%
# !pip install jupyterlab==4.0.0
# Out:
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.2 MB 4.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/9.2 MB 7.4 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/9.2 MB 7.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/9.2 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/9.2 MB 5.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.4/9.2 MB 5.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.2 MB 5.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.2 MB 4.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.2 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/9.2 MB 4.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.3/9.2 MB 4.6 MB/s eta 0:00:02
# ...

# %%
# !jupyter lab
# Out:
# ^C

# %%
# %load_ext jupyter_ai_magics
# %ai list
# Out:
# ai21
# Requires environment variable AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-tg1-large
# * bedrock:anthropic.claude-v1
# * bedrock:anthropic.claude-instant-v1
# * bedrock:anthropic.claude-v2
# * bedrock:ai21.j2-jumbo-instruct
# * bedrock:ai21.j2-grande-instruct
#
# anthropic
# Requires environment variable ANTHROPIC_API_KEY (not set)
# * anthropic:claude-v1
# * anthropic:claude-v1.0
# * anthropic:claude-v1.2
# * anthropic:claude-2
# * anthropic:claude-instant-v1
# * anthropic:claude-instant-v1.0
#
# cohere
# Requires environment variable COHERE_API_KEY (set)
# * cohere:medium
# * cohere:xlarge
#
# huggingface_hub
# Requires environment variable HUGGINGFACEHUB_API_TOKEN (not set)
# ...

# %%
# %env COHERE_API_KEY = {YOUR_API_KEY}
# %env COHERE_API_KEY = KDDuN63DoU9RCkuywQT0Jgq54G0e1c3BaPoR3mtA
# Out:
# env: COHERE_API_KEY=KDDuN63DoU9RCkuywQT0Jgq54G0e1c3BaPoR3mtA

# %%
# %%ai cohere:command
# Explain the Monty Hall problem in brief.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'cohere:command', 'Explain the Monty Hall problem in brief.\n')
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2475, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2473 with self.builtin_trap:
#    2474     args = (magic_arg_s, cell)
# -> 2475     result = fn(*args, **kwargs)
#    2477 # The code below prevents the output from being displayed
#    2478 # when using magics with decodator @output_can_be_silenced
#    2479 # when the last Python token in the expression is a ';'.
#    2480 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\lib\site-packages\jupyter_ai_magics\magics.py:590, in AiMagics.ai(self, line, cell)
#     587 ip = get_ipython()
# ...

# %%
# 1. install cohere
# !pip install cohere --upgrade

# %%
# !pip install transformers --upgrade
# Out:
# ...
#                                               0.0/9.0 MB ? eta -:--:--
#                                               0.2/9.0 MB 6.1 MB/s eta 0:00:02
#      ---                                      0.7/9.0 MB 8.8 MB/s eta 0:00:01
#      ---                                      0.9/9.0 MB 7.0 MB/s eta 0:00:02
#      ----                                     1.1/9.0 MB 6.1 MB/s eta 0:00:02
#      -----                                    1.2/9.0 MB 6.2 MB/s eta 0:00:02
#      -----                                    1.2/9.0 MB 6.2 MB/s eta 0:00:02
#      -----                                    1.2/9.0 MB 6.2 MB/s eta 0:00:02
#      -------                                  1.8/9.0 MB 5.1 MB/s eta 0:00:02
#      --------                                 2.0/9.0 MB 5.0 MB/s eta 0:00:02
#      ---------                                2.1/9.0 MB 4.9 MB/s eta 0:00:02
#      ----------                               2.3/9.0 MB 4.8 MB/s eta 0:00:02
# ...

# %%
import cohere

# %%
co = cohere.Client(
    api_key="KDDuN63DoU9RCkuywQT0Jgq54G0e1c3BaPoR3mtA",
)

chat = co.chat(
    message="hello world!",
    model="command"
)

print(chat)
# Out:
# text="Hi there! I'm Coral, an AI-assistant chatbot trained to assist human users by providing helpful responses. How can I help you today?\n I'm excited to talk with you and help however I can! \n\nLet me know if there's something in particular you'd like to talk about, or if you have any questions you need answered. I'll do my best to provide you with helpful and thorough responses. \n\nUntil then, keep exploring, stay curious, and keep coming back for meaningful conversations!" generation_id='141ff2a2-9d71-4f61-93e2-e1290a00aa2a' citations=None documents=None is_search_required=None search_queries=None search_results=None finish_reason='COMPLETE' tool_calls=None chat_history=[ChatMessage(role='USER', message='hello world!'), ChatMessage(role='CHATBOT', message="Hi there! I'm Coral, an AI-assistant chatbot trained to assist human users by providing helpful responses. How can I help you today?\n I'm excited to talk with you and help however I can! \n\nLet me know if there's something
# ...
